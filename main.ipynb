# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratt33/Amazon-ml-challenge/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
import pandas as pd

# Add the src directory to the system path
sys.path.append('/content/student_resource_3/src')

from utils import download_images

# Load the dataset (assuming train.csv)
train_data = pd.read_csv('/content/student_resource_3/dataset/train.csv')

# Extract image links and indices
image_links = train_data['image_link']
image_indices = train_data['group_id']

# Download images using the helper function
for idx, url in zip(image_indices, image_links):
    download_images(url, f'images/{idx}.jpg')  # Save images with index as filename
# Out:
# ...
#   0%|          | 0/51 [00:00<?, ?it/s]
